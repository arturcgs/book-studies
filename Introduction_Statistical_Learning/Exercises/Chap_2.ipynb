# %% [markdown]
# <a href="https://colab.research.google.com/github/arturcgs/IntroductionToStatisticalLearning/blob/main/Exercises/Chap_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
dados = pd.read_csv('https://raw.githubusercontent.com/arturcgs/IntroductionToStatisticalLearning/main/DataSets/College.csv')
dados
# Out:
#                          Unnamed: 0 Private  ...  Expend  Grad.Rate
# 0      Abilene Christian University     Yes  ...    7041         60
# 1                Adelphi University     Yes  ...   10527         56
# 2                    Adrian College     Yes  ...    8735         54
# 3               Agnes Scott College     Yes  ...   19016         59
# 4         Alaska Pacific University     Yes  ...   10922         15
# ..                              ...     ...  ...     ...        ...
# 772         Worcester State College      No  ...    4469         40
# 773               Xavier University     Yes  ...    9189         83
# 774  Xavier University of Louisiana     Yes  ...    8323         49
# 775                 Yale University     Yes  ...   40386         99
# 776    York College of Pennsylvania     Yes  ...    4509         99
#
# [777 rows x 19 columns]

# %%
dados.columns.values
# Out:
# array(['Unnamed: 0', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate',
#        'Room.Board', 'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio',
#        'perc.alumni', 'Expend', 'Grad.Rate'], dtype=object)

# %%
dados = dados.set_index('Unnamed: 0')

dados
# Out:
#                                Private   Apps  ...  Expend  Grad.Rate
# Unnamed: 0                                     ...
# Abilene Christian University       Yes   1660  ...    7041         60
# Adelphi University                 Yes   2186  ...   10527         56
# Adrian College                     Yes   1428  ...    8735         54
# Agnes Scott College                Yes    417  ...   19016         59
# Alaska Pacific University          Yes    193  ...   10922         15
# ...                                ...    ...  ...     ...        ...
# Worcester State College             No   2197  ...    4469         40
# Xavier University                  Yes   1959  ...    9189         83
# Xavier University of Louisiana     Yes   2097  ...    8323         49
# Yale University                    Yes  10705  ...   40386         99
# York College of Pennsylvania       Yes   2989  ...    4509         99
#
# [777 rows x 18 columns]

# %%
dados.describe()
# Out:
#                Apps        Accept  ...        Expend  Grad.Rate
# count    777.000000    777.000000  ...    777.000000  777.00000
# mean    3001.638353   2018.804376  ...   9660.171171   65.46332
# std     3870.201484   2451.113971  ...   5221.768440   17.17771
# min       81.000000     72.000000  ...   3186.000000   10.00000
# 25%      776.000000    604.000000  ...   6751.000000   53.00000
# 50%     1558.000000   1110.000000  ...   8377.000000   65.00000
# 75%     3624.000000   2424.000000  ...  10830.000000   78.00000
# max    48094.000000  26330.000000  ...  56233.000000  118.00000
#
# [8 rows x 17 columns]

# %%
sns.pairplot(dados.iloc[:, :9])

# %%
sns.pairplot(dados.iloc[:, :9], hue='Private')

# %%
sns.boxplot(y='Outstate', data = dados, x='Private')

# %%
len(dados)
# Out:
# 777

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dados['Elite'] = 'Não'

dados['Elite'] = np.where(dados['Top10perc'] > 50, 'yes', 'no')

dados
# Out:
#                                Private   Apps  Accept  ...  Expend  Grad.Rate  Elite
# Unnamed: 0                                             ...
# Abilene Christian University       Yes   1660    1232  ...    7041         60     no
# Adelphi University                 Yes   2186    1924  ...   10527         56     no
# Adrian College                     Yes   1428    1097  ...    8735         54     no
# Agnes Scott College                Yes    417     349  ...   19016         59    yes
# Alaska Pacific University          Yes    193     146  ...   10922         15     no
# ...                                ...    ...     ...  ...     ...        ...    ...
# Worcester State College             No   2197    1515  ...    4469         40     no
# Xavier University                  Yes   1959    1805  ...    9189         83     no
# Xavier University of Louisiana     Yes   2097    1915  ...    8323         49     no
# ...

# %%
dados['Elite'].value_counts()
# Out:
# no     699
# yes     78
# Name: Elite, dtype: int64

# %%
sns.boxplot(y='Outstate', data = dados, x='Elite')

# %%
fig, axs = plt.subplots(ncols=3)

sns.histplot(data = dados, x = 'Apps', ax=axs[0])
sns.histplot(data = dados, x = 'Accept', ax=axs[1])
sns.histplot(data = dados, x = 'Outstate', ax=axs[2])

# %%
dados['Universidades'] = dados.index

dados_long = dados.melt(id_vars='Universidades', var_name='key', value_name='value')

dados_long
# Out:
#                         Universidades      key value
# 0        Abilene Christian University  Private   Yes
# 1                  Adelphi University  Private   Yes
# 2                      Adrian College  Private   Yes
# 3                 Agnes Scott College  Private   Yes
# 4           Alaska Pacific University  Private   Yes
# ...                               ...      ...   ...
# 14758         Worcester State College    Elite    no
# 14759               Xavier University    Elite    no
# 14760  Xavier University of Louisiana    Elite    no
# 14761                 Yale University    Elite   yes
# 14762    York College of Pennsylvania    Elite    no
#
# [14763 rows x 3 columns]

# %%
dados_hist = dados_long.query('key == "Apps" | key == "Accept" | key == "Enroll"')

dados_hist
# Out:
#                        Universidades     key value
# 777     Abilene Christian University    Apps  1660
# 778               Adelphi University    Apps  2186
# 779                   Adrian College    Apps  1428
# 780              Agnes Scott College    Apps   417
# 781        Alaska Pacific University    Apps   193
# ...                              ...     ...   ...
# 3103         Worcester State College  Enroll   543
# 3104               Xavier University  Enroll   695
# 3105  Xavier University of Louisiana  Enroll   695
# 3106                 Yale University  Enroll  1317
# 3107    York College of Pennsylvania  Enroll   691
#
# [2331 rows x 3 columns]

# %%
sns.displot(dados_hist, x = 'value', col = 'key')
